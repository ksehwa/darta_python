# %%
import pandas as pd
import re, os
os.chdir(r'C:\Users\kke86\OneDrive\바탕 화면\data_python\data_python\Basic')

# %%
df = pd.read_csv('apt.csv',encoding = 'cp949')

# %%
len(df)
# Out:
# 42758

# %% [markdown]
# 처음이나 마지막 자료 일부 출력

# %%
df.head()
# Out:
#             지역   번지   본번  부번           아파트       면적    계약년월  계약일     가격   층  \
# 0  강원도 강릉시 견소동  202  202   0          송정한신   59.800  201910    4  10900   5
# 1  강원도 강릉시 견소동  202  202   0          송정한신  116.175  201910   31  18500  10
# 2  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   84.990  201910    5  25000   6
# 3  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   84.990  201910   12  20600   3
# 4  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   84.990  201910   20  20500   1
#
#    건축년도           도로명
# 0  1997   경강로2539번길 8
# 1  1997   경강로2539번길 8
# 2  2005  경강로2539번길 22
# 3  2005  경강로2539번길 22
# 4  2005  경강로2539번길 22

# %%
df.tail()
# Out:
#                  지역      번지   본번  부번         아파트     면적    계약년월  계약일     가격  \
# 42753  충청북도 충주시 호암동   547-6  547   6        호반현대  59.76  201910   29   7000
# 42754  충청북도 충주시 호암동  221-23  221  23  호암리버빌(1단지)  84.68  201910    5  12000
# 42755  충청북도 충주시 호암동  221-23  221  23  호암리버빌(1단지)  84.68  201910   15  11000
# 42756  충청북도 충주시 호암동  221-23  221  23  호암리버빌(1단지)  84.68  201910   17  12000
# 42757  충청북도 충주시 호암동  221-23  221  23  호암리버빌(1단지)  84.68  201910   26  11200
#
#         층  건축년도       도로명
# 42753   3  1994   신촌2길 28
# 42754  15  2002  원호암5길 32
# 42755   7  2002  원호암5길 32
# 42756  14  2002  원호암5길 32
# 42757  11  2002  원호암5길 32

# %% [markdown]
# 열 전체 자료 출력

# %%
df.지역
# Out:
# 0         강원도 강릉시 견소동
# 1         강원도 강릉시 견소동
# 2         강원도 강릉시 견소동
# 3         강원도 강릉시 견소동
# 4         강원도 강릉시 견소동
#              ...
# 42753    충청북도 충주시 호암동
# 42754    충청북도 충주시 호암동
# 42755    충청북도 충주시 호암동
# 42756    충청북도 충주시 호암동
# 42757    충청북도 충주시 호암동
# Name: 지역, Length: 42758, dtype: object

# %% [markdown]
# 조건별 출력

# %%
df.면적 > 130       # 면적이 103이 넘는 값은 True, 아니라면 False로 나눠서 보여줌
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 42753    False
# 42754    False
# 42755    False
# 42756    False
# 42757    False
# Name: 면적, Length: 42758, dtype: bool

# %%
df[df.면적 > 130]     # 면적이 130을 넘는 데이터프레임만 출력
# Out:
#                  지역       번지    본번  부번          아파트        면적    계약년월  계약일  \
# 6        강원도 강릉시 교동     1982  1982   0  강릉교동롯데캐슬1단지  135.1727  201910   21
# 39      강원도 강릉시 남문동    183-2   183   2       삼익그린맨션  164.7540  201910   15
# 334     강원도 속초시 금호동      629   629   0     보람레이크더하임  156.7600  201910   16
# 433     강원도 원주시 개운동  01월 28일    28   1      원주힐스테이트  133.9912  201910    5
# 434     강원도 원주시 개운동  01월 28일    28   1      원주힐스테이트  137.4292  201910   31
# ...             ...      ...   ...  ..          ...       ...     ...  ...
# 42595  충청북도 충주시 문화동     2260  2260   0           럭키  156.7900  201910   21
# 42607  충청북도 충주시 안림동     1166  1166   0         엘리시아  136.1287  201910   19
# 42663  충청북도 충주시 연수동     1627  1627   0      연수힐스테이트  143.2109  201910   14
# 42736  충청북도 충주시 칠금동      626   626   0           삼일  143.5800  201910   20
# 42737  충청북도 충주시 칠금동      626   626   0           삼일  143.5800  201910   21
#
#           가격   층  건축년도           도로명
# ...

# %%
df.가격[df.면적 > 130]    # 면적이 103을 넘는 아파트의 가격
# Out:
# 6        34300
# 39       21000
# 334      29500
# 433      26000
# 434      24000
#          ...
# 42595    15000
# 42607    18500
# 42663    31500
# 42736    18500
# 42737    16200
# Name: 가격, Length: 1567, dtype: int64

# %%
df.가격[(df.면적 > 130) & (df.가격 < 15000)]    #면적은 130이 넘고 가격은 2억 원 미만
# Out:
# 862      14900
# 927      13800
# 16785    14700
# 36733    14700
# 37726    13700
# 38811    14600
# 39487    12000
# 40680    12500
# 41173    14000
# 41578    13000
# Name: 가격, dtype: int64

# %% [markdown]
# 원하는 자료만 확인

# %%
df.loc[:10, ['아파트','가격']]     # '아파트'와 '가격' 자료만 10번 까지 출력
# Out:
#                 아파트     가격
# 0              송정한신  10900
# 1              송정한신  18500
# 2      송정해변신도브래뉴아파트  25000
# 3      송정해변신도브래뉴아파트  20600
# 4      송정해변신도브래뉴아파트  20500
# 5   강릉 교동 풍림아이원 아파트  29200
# 6       강릉교동롯데캐슬1단지  34300
# 7       강릉교동롯데캐슬2단지  32500
# 8             교동1주공  16200
# 9             교동1주공  21550
# 10            교동1주공  21800

# %%
df.loc[:, ['아파트','가격']] [df.가격 > 40000]
# Out:
#                   아파트     가격
# 382          속초청호아이파크  45800
# 541          무실e-편한세상  44600
# 592          원주반곡아이파크  40700
# 842    온의 롯데캐슬 스카이클래스  44000
# 843    온의 롯데캐슬 스카이클래스  42900
# ...               ...    ...
# 42364       신영지웰시티 1차  47700
# 42365       신영지웰시티 1차  46000
# 42366       신영지웰시티 1차  55800
# 42367       신영지웰시티 1차  67000
# 42424          봉명아이파크  49000
#
# [10486 rows x 2 columns]

# %% [markdown]
# 새로운 값 추가

# %%
df['단가'] = df.가격/ df.면적
df.loc[:10,('가격','면적','단가')]
# Out:
#        가격        면적          단가
# 0   10900   59.8000  182.274247
# 1   18500  116.1750  159.242522
# 2   25000   84.9900  294.152253
# 3   20600   84.9900  242.381457
# 4   20500   84.9900  241.204848
# 5   29200   84.9964  343.543962
# 6   34300  135.1727  253.749463
# 7   32500  118.0686  275.263703
# 8   16200   59.8900  270.495909
# 9   21550   84.8400  254.007544
# 10  21800   84.8400  256.954267

# %% [markdown]
# 데이터 정렬하기

# %%
df.sort_values(by = '가격').loc[:, ('가격','지역')]   # 오름차순 정렬  / 가격이 가장 싼아파트부터 가격과 지역만 출력
# Out:
#            가격                지역
# 17024     600      경상북도 구미시 원평동
# 17022     700      경상북도 구미시 원평동
# 17637     750  경상북도 칠곡군 약목면 관호리
# 17031     800      경상북도 구미시 원평동
# 17027     800      경상북도 구미시 원평동
# ...       ...               ...
# 27036  373000     서울특별시 강남구 대치동
# 26805  376640     부산광역시 해운대구 우동
# 29946  415000     서울특별시 서초구 반포동
# 27061  461000     서울특별시 강남구 도곡동
# 31258  485000     서울특별시 용산구 한남동
#
# [42758 rows x 2 columns]

# %%
df.sort_values(by = '가격', ascending=False).loc[:, ('가격','지역')]     # 내림차순으로 다시 정렬
# Out:
#            가격                지역
# 31258  485000     서울특별시 용산구 한남동
# 27061  461000     서울특별시 강남구 도곡동
# 29946  415000     서울특별시 서초구 반포동
# 26805  376640     부산광역시 해운대구 우동
# 27036  373000     서울특별시 강남구 대치동
# ...       ...               ...
# 17027     800      경상북도 구미시 원평동
# 17025     800      경상북도 구미시 원평동
# 17637     750  경상북도 칠곡군 약목면 관호리
# 17022     700      경상북도 구미시 원평동
# 17024     600      경상북도 구미시 원평동
#
# [42758 rows x 2 columns]

# %%
df[df.가격 > 40000].sort_values(by='면적').loc[:,('가격','면적','지역')]
# Out:
#            가격        면적               지역
# 30111   90000   25.3284  서울특별시 성동구 성수동1가
# 27124   74000   28.2460    서울특별시 강남구 역삼동
# 27122   74500   28.2460    서울특별시 강남구 역삼동
# 27123   76000   28.2460    서울특별시 강남구 역삼동
# 29725   43500   30.0100    서울특별시 마포구 아현동
# ...       ...       ...              ...
# 27118  245000  242.8200    서울특별시 강남구 역삼동
# 30002  206000  244.4200    서울특별시 서초구 서초동
# 10106  100000  244.6630    경기도 용인수지구 성복동
# 31501  240000  273.8200     서울특별시 중구 신당동
# 35826  300000  291.3360    인천광역시 연수구 송도동
#
# [10486 rows x 3 columns]

# %% [markdown]
# 문자열 다루기

# %%
df.head()
# Out:
#             지역   번지   본번  부번           아파트       면적    계약년월  계약일     가격   층  \
# 0  강원도 강릉시 견소동  202  202   0          송정한신   59.800  201910    4  10900   5
# 1  강원도 강릉시 견소동  202  202   0          송정한신  116.175  201910   31  18500  10
# 2  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   84.990  201910    5  25000   6
# 3  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   84.990  201910   12  20600   3
# 4  강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   84.990  201910   20  20500   1
#
#    건축년도           도로명          단가
# 0  1997   경강로2539번길 8  182.274247
# 1  1997   경강로2539번길 8  159.242522
# 2  2005  경강로2539번길 22  294.152253
# 3  2005  경강로2539번길 22  242.381457
# 4  2005  경강로2539번길 22  241.204848

# %%
df.지역.str.find('강릉')
# Out:
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
#         ..
# 42753   -1
# 42754   -1
# 42755   -1
# 42756   -1
# 42757   -1
# Name: 지역, Length: 42758, dtype: int64

# %%
df[df.지역.str.find('강릉') > -1]         # 지역에 '강릉'이 들어간 자료만 따로 모아 출력
# Out:
#               지역   번지   본번  부번           아파트        면적    계약년월  계약일     가격  \
# 0    강원도 강릉시 견소동  202  202   0          송정한신   59.8000  201910    4  10900
# 1    강원도 강릉시 견소동  202  202   0          송정한신  116.1750  201910   31  18500
# 2    강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   84.9900  201910    5  25000
# 3    강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   84.9900  201910   12  20600
# 4    강원도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트   84.9900  201910   20  20500
# ..           ...  ...  ...  ..           ...       ...     ...  ...    ...
# 183  강원도 강릉시 회산동  608  608   0  강릉서희스타힐스리버파크   84.8956  201910   24  24000
# 184  강원도 강릉시 회산동  130  130   0      힐스테이트 강릉   84.9925  201910    7  24000
# 185  강원도 강릉시 회산동  130  130   0      힐스테이트 강릉   74.9974  201910   19  23000
# 186  강원도 강릉시 회산동  130  130   0      힐스테이트 강릉   74.9985  201910   21  24100
# 187  강원도 강릉시 회산동  130  130   0      힐스테이트 강릉   74.9974  201910   29  25400
#
#       층  건축년도           도로명          단가
# ...

# %%
dfF = df[df.지역.str.find('강릉') > -1] 
dfF.mean()
# Out:
# C:\Users\kke86\AppData\Local\Temp\ipykernel_18888\2383302120.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dfF.mean()
# 본번               inf
# 부번      1.085106e+00
# 면적      7.047780e+01
# 계약년월    2.019100e+05
# 계약일     1.527128e+01
# 가격      1.541457e+04
# 층       7.420213e+00
# 건축년도    2.000463e+03
# 단가      2.099422e+02
# dtype: float64

# %% [markdown]
# 콤마가 있는 자료 정리

# %%
df = pd.read_csv('apt_comma.csv', encoding='cp949')

# %%
df.가격 = df.가격.str.replace(',','').astype('int64')      # '가격' 정보를 '문자'로 인식하고 쉼표(,) 제거 후 정수로 변경
df[df.가격 > 40000]
# Out:
#                       시군구          단지명        면적    계약년월  계약일     가격   층  \
# 24             강원도 강릉시 교동  강릉교동롯데캐슬1단지  163.9852  202002   15  42000   7
# 26             강원도 강릉시 교동  강릉교동롯데캐슬1단지  163.9852  202002   18  44000   5
# 27             강원도 강릉시 교동  강릉교동롯데캐슬1단지  164.0098  202002   19  41900  11
# 28             강원도 강릉시 교동  강릉교동롯데캐슬1단지  163.9852  202002   19  43400   9
# 617           강원도 속초시 청호동     속초청호아이파크   84.9400  202002    1  43000  14
# ...                   ...          ...       ...     ...  ...    ...  ..
# 72518      충청북도 청주흥덕구 복대동    신영지웰시티 1차   99.1260  202002   29  45600  31
# 72536      충청북도 청주흥덕구 복대동          어울림  163.8470  202002    8  44700  14
# 72537      충청북도 청주흥덕구 복대동          어울림  163.8470  202002   22  40900   9
# 72741  충청북도 청주흥덕구 오송읍 연제리      오송힐데스하임  174.7978  202002    1  51500   7
# 72744  충청북도 청주흥덕구 오송읍 연제리      오송힐데스하임  174.7978  202002   19  52000  15
#
#        건축년도          도로명
# 24     2009  화부산로99번길 12
# 26     2009  화부산로99번길 12
# ...
